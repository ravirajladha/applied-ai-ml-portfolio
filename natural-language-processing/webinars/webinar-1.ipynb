# %% [markdown]
# # Webinar 1 — Intro to Tokenization & Embeddings
#
# Working-example notebook. Accompanying data: `webinar-1-data.xlsx`.

# %%
import pandas as pd

df = pd.read_excel('webinar-1-data.xlsx')
df.head()
